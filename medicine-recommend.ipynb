# %% [markdown]
# **CodeClause- "DATA SCIENCE INTERN "**

# %% [markdown]
# **Golden Project - 2**

# %% [markdown]
# **AUTHOR - PARAG PATIL**

# %% [markdown]
# **TASK 1- Wine Quality PREDICTON**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
medicines = pd.read_csv('medicine.csv')

# %%
medicines.head()
# Out:
#    index                                          Drug_Name Reason  \
# 0      1               A CN Gel(Topical) 20gmA CN Soap 75gm   Acne
# 1      2  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...   Acne
# 2      3                             ACGEL CL NANO Gel 15gm   Acne
# 3      4                                ACGEL NANO Gel 15gm   Acne
# 4      5                              Acleen 1% Lotion 25ml   Acne
#
#                                          Description
# 0                      Mild to moderate acne (spots)
# 1  A RET 0.025% is a prescription medicine that i...
# 2  It is used to treat acne vulgaris in people 12...
# 3  It is used to treat acne vulgaris in people 12...
# 4  treat the most severe form of acne (nodular ac...

# %%
medicines.shape
# Out:
# (9720, 4)

# %%
medicines.isnull().sum()
# Out:
# index          0
# Drug_Name      0
# Reason         0
# Description    0
# dtype: int64

# %%
medicines.dropna(inplace=True)

# %%
medicines.duplicated().sum()
# Out:
# 0

# %%
medicines['Description']
# Out:
# 0                           Mild to moderate acne (spots)
# 1       A RET 0.025% is a prescription medicine that i...
# 2       It is used to treat acne vulgaris in people 12...
# 3       It is used to treat acne vulgaris in people 12...
# 4       treat the most severe form of acne (nodular ac...
# 5       treat the most severe form of acne (nodular ac...
# 6       treat the most severe form of acne (nodular ac...
# 7                                 Â treat acne vulgarisÂ
# 8                                 Â treat acne vulgarisÂ
# 9                    Â treat mild to moderate acne(spots)
# 10      treatment of dry scaly skin disorders of the s...
# 11                          Mild to moderate acne (spots)
# 12      A RET 0.025% is a prescription medicine that i...
# 13      It is used to treat acne vulgaris in people 12...
# 14      It is used to treat acne vulgaris in people 12...
# 15      treat the most severe form of acne (nodular ac...
# 16      treat the most severe form of acne (nodular ac...
# 17      treat the most severe form of acne (nodular ac...
# 18                                Â treat acne vulgarisÂ
# 19                                Â treat acne vulgarisÂ
# 20                   Â treat mild to moderate acne(spots)
# 21      treatment of dry scaly skin disorders of the s...
# 22      combined with anti-acne actives of both natura...
# 23      Â gives smooth, soft, supple and fresh feeling...
# 24      It helps to reduce swelling. It can help reduc...
# 25                          Mild to moderate acne (spots)
# 26      A RET 0.025% is a prescription medicine that i...
# 27      It is used to treat acne vulgaris in people 12...
# 28      It is used to treat acne vulgaris in people 12...
# 29      treat the most severe form of acne (nodular ac...
#                               ...
# 9690    used to treat and remove raised warts (usually...
# 9691                              used for treating warts
# 9692                        used to soften the skin cells
# 9693                                       used for scars
# 9694                                      used for wounds
# 9695    used to treat and remove raised warts (usually...
# 9696                              used for treating warts
# 9697    used to treat and remove raised warts (usually...
# 9698                              used for treating warts
# 9699                        used to soften the skin cells
# 9700                                       used for scars
# 9701                                      used for wounds
# 9702    used to treat and remove raised warts (usually...
# 9703                              used for treating warts
# 9704                        used to soften the skin cells
# 9705                                       used for scars
# 9706                                      used for wounds
# 9707    used to treat and remove raised warts (usually...
# 9708                              used for treating warts
# 9709    used to treat and remove raised warts (usually...
# 9710                              used for treating warts
# 9711                        used to soften the skin cells
# 9712                                       used for scars
# 9713                                      used for wounds
# 9714    used to treat and remove raised warts (usually...
# 9715                              used for treating warts
# 9716                        used to soften the skin cells
# 9717                                       used for scars
# 9718                                      used for wounds
# 9719    used to treat and remove raised warts (usually...
# Name: Description, Length: 9720, dtype: object

# %%
medicines['Description'].apply(lambda x:x.split())
# Out:
# 0                     [Mild, to, moderate, acne, (spots)]
# 1       [A, RET, 0.025%, is, a, prescription, medicine...
# 2       [It, is, used, to, treat, acne, vulgaris, in, ...
# 3       [It, is, used, to, treat, acne, vulgaris, in, ...
# 4       [treat, the, most, severe, form, of, acne, (no...
# 5       [treat, the, most, severe, form, of, acne, (no...
# 6       [treat, the, most, severe, form, of, acne, (no...
# 7                             [Â, treat, acne, vulgarisÂ]
# 8                             [Â, treat, acne, vulgarisÂ]
# 9             [Â, treat, mild, to, moderate, acne(spots)]
# 10      [treatment, of, dry, scaly, skin, disorders, o...
# 11                    [Mild, to, moderate, acne, (spots)]
# 12      [A, RET, 0.025%, is, a, prescription, medicine...
# 13      [It, is, used, to, treat, acne, vulgaris, in, ...
# 14      [It, is, used, to, treat, acne, vulgaris, in, ...
# 15      [treat, the, most, severe, form, of, acne, (no...
# 16      [treat, the, most, severe, form, of, acne, (no...
# 17      [treat, the, most, severe, form, of, acne, (no...
# 18                            [Â, treat, acne, vulgarisÂ]
# 19                            [Â, treat, acne, vulgarisÂ]
# 20            [Â, treat, mild, to, moderate, acne(spots)]
# 21      [treatment, of, dry, scaly, skin, disorders, o...
# 22      [combined, with, anti-acne, actives, of, both,...
# 23      [Â, gives, smooth,, soft,, supple, and, fresh,...
# 24      [It, helps, to, reduce, swelling., It, can, he...
# 25                    [Mild, to, moderate, acne, (spots)]
# 26      [A, RET, 0.025%, is, a, prescription, medicine...
# 27      [It, is, used, to, treat, acne, vulgaris, in, ...
# 28      [It, is, used, to, treat, acne, vulgaris, in, ...
# 29      [treat, the, most, severe, form, of, acne, (no...
#                               ...
# 9690    [used, to, treat, and, remove, raised, warts, ...
# 9691                         [used, for, treating, warts]
# 9692                 [used, to, soften, the, skin, cells]
# 9693                                   [used, for, scars]
# 9694                                  [used, for, wounds]
# 9695    [used, to, treat, and, remove, raised, warts, ...
# 9696                         [used, for, treating, warts]
# 9697    [used, to, treat, and, remove, raised, warts, ...
# 9698                         [used, for, treating, warts]
# 9699                 [used, to, soften, the, skin, cells]
# 9700                                   [used, for, scars]
# 9701                                  [used, for, wounds]
# 9702    [used, to, treat, and, remove, raised, warts, ...
# 9703                         [used, for, treating, warts]
# 9704                 [used, to, soften, the, skin, cells]
# 9705                                   [used, for, scars]
# 9706                                  [used, for, wounds]
# 9707    [used, to, treat, and, remove, raised, warts, ...
# 9708                         [used, for, treating, warts]
# 9709    [used, to, treat, and, remove, raised, warts, ...
# 9710                         [used, for, treating, warts]
# 9711                 [used, to, soften, the, skin, cells]
# 9712                                   [used, for, scars]
# 9713                                  [used, for, wounds]
# 9714    [used, to, treat, and, remove, raised, warts, ...
# 9715                         [used, for, treating, warts]
# 9716                 [used, to, soften, the, skin, cells]
# 9717                                   [used, for, scars]
# 9718                                  [used, for, wounds]
# 9719    [used, to, treat, and, remove, raised, warts, ...
# Name: Description, Length: 9720, dtype: object

# %%
medicines['Reason'] = medicines['Reason'].apply(lambda x:x.split())
medicines['Description'] = medicines['Description'].apply(lambda x:x.split())

# %%
medicines['Description'] = medicines['Description'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
medicines['Description'] = medicines['Description'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
medicines['tags'] = medicines['Description'] + medicines['Reason']

# %%
new_df = medicines[['index','Drug_Name','tags']]

# %%
new_df
# Out:
#       index                                          Drug_Name  \
# 0         1               A CN Gel(Topical) 20gmA CN Soap 75gm
# 1         2  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...
# 2         3                             ACGEL CL NANO Gel 15gm
# 3         4                                ACGEL NANO Gel 15gm
# 4         5                              Acleen 1% Lotion 25ml
# 5         6                              Aclene 0.10% Gel 15gm
# 6         7                                     Acnay Gel 10gm
# 7         8                Acne Aid Bar 50gmAcne Aid Bar 100gm
# 8         9                                   Acne UV Gel 60gm
# 9        10                            Acne UV SPF 30 Gel 30gm
# 10       11                                  Acnecure Gel 20gm
# 11       12                                   Acnedap Gel 15gm
# 12       13                              Acnedap Plus Gel 15gm
# 13       14                                   Acnehit Gel 15gm
# 14       15                                  Acnelak Soap 75gm
# 15       16                             Acnelak Clz Cream 15gm
# 16       17                              Acnelak Z Lotion 15gm
# 17       18                               Acnemoist Cream 60gm
# 18       19                                  Acnerex Soap 75gm
# 19       20  Acneril 1% Gel 10gmAcneril Tablet 10Acneril 0....
# 20       21  Acnesol 1% Solution 25mlAcnesol Gel 20gmAcneso...
# 21       22                            Acnesol A Nano Gel 15gm
# 22       23                                Acnesol CL Gel 15gm
# 23       24                                 Acnestal Soap 75gm
# 24       25  Acnestar 10mg Capsule 10'SAcnestar 2.5% Soap 7...
# 25       26        Acnetoin 20mg Capsule 10'SAcnetoin Gel 15gm
# 26       27                         Acnetoin Plus Oinment 15gm
# 27       28                        Acnetor AD 1% Ointment 15gm
# 28       29             Acnetor AD Cream 15Acnetor AD Gel 15gm
# 29       30                                   Acnewar Gel 15gm
# ...     ...                                                ...
# 9690   9691                         Hydroheal AM Ointment 15gm
# 9691   9692         Hydroheal AM Gel 50gmHydroheal AM Gel 15gm
# 9692   9693                    Hydroheal Silwash Solution 60ml
# 9693   9694  Intadine 5% Oinment 250gmIntadine Solution 500...
# 9694   9695                     Intadine HS 10% Solution 100ml
# 9695   9696                              Iteol 3 Liquid 1000ml
# 9696   9697                              Iteol H Solution 5Ltr
# 9697   9698  Placentrex CreamPlacentrex Cream 20gmPlacentre...
# 9698   9699                              Placentrex V Gel 20gm
# 9699   9700                                POVICIDAL Gel 250gm
# 9700   9701                               POVID Solution 100ml
# 9701   9702                         Povidine 5% Solution 500ml
# 9702   9703                      Povidone Iodine Ointment 20gm
# 9703   9704  Povimac Oinment 15gmPovimac Oinment 10gmPovima...
# 9704   9705                                Povimed Oinment 5gm
# 9705   9706                               Povimet Oinment 15gm
# 9706   9707                             Puridine Ointment 15gm
# 9707   9708                 Scarend Silicone Gel(Topical) 10gm
# 9708   9709                              Sepovin Ointment 15gm
# 9709   9710  Servinadine Ointment 10gmServinadine Ointment ...
# 9710   9711                             Silverex Heal Gel 15gm
# 9711   9712                           Silverex Ionic Gel 100gm
# 9712   9713                              Soludine M Cream 10gm
# 9713   9714                          Sucral Povi Ointment 20gm
# 9714   9715                              Supraheal AR Gel 20gm
# 9715   9716                                T Muce Ointment 5gm
# 9716   9717  Wokadine 10% Solution 100mlWokadine Solution 5...
# 9717   9718                               Wokadine M Onit 10gm
# 9718   9719                           Wound Fix Solution 100ml
# 9719   9720                              Wounsol Ointment 15gm
#
#                                                    tags
# 0             [Mild, to, moderate, acne, (spots), Acne]
# 1     [A, RET, 0.025%, is, a, prescription, medicine...
# 2     [It, is, used, to, treat, acne, vulgaris, in, ...
# 3     [It, is, used, to, treat, acne, vulgaris, in, ...
# 4     [treat, the, most, severe, form, of, acne, (no...
# 5     [treat, the, most, severe, form, of, acne, (no...
# 6     [treat, the, most, severe, form, of, acne, (no...
# 7                     [Â, treat, acne, vulgarisÂ, Acne]
# 8                     [Â, treat, acne, vulgarisÂ, Acne]
# 9     [Â, treat, mild, to, moderate, acne(spots), Acne]
# 10    [treatment, of, dry, scaly, skin, disorders, o...
# 11            [Mild, to, moderate, acne, (spots), Acne]
# 12    [A, RET, 0.025%, is, a, prescription, medicine...
# 13    [It, is, used, to, treat, acne, vulgaris, in, ...
# 14    [It, is, used, to, treat, acne, vulgaris, in, ...
# 15    [treat, the, most, severe, form, of, acne, (no...
# 16    [treat, the, most, severe, form, of, acne, (no...
# 17    [treat, the, most, severe, form, of, acne, (no...
# 18                    [Â, treat, acne, vulgarisÂ, Acne]
# 19                    [Â, treat, acne, vulgarisÂ, Acne]
# 20    [Â, treat, mild, to, moderate, acne(spots), Acne]
# 21    [treatment, of, dry, scaly, skin, disorders, o...
# 22    [combined, with, anti-acne, actives, of, both,...
# 23    [Â, gives, smooth,, soft,, supple, and, fresh,...
# 24    [It, helps, to, reduce, swelling., It, can, he...
# 25            [Mild, to, moderate, acne, (spots), Acne]
# 26    [A, RET, 0.025%, is, a, prescription, medicine...
# 27    [It, is, used, to, treat, acne, vulgaris, in, ...
# 28    [It, is, used, to, treat, acne, vulgaris, in, ...
# 29    [treat, the, most, severe, form, of, acne, (no...
# ...                                                 ...
# 9690  [used, to, treat, and, remove, raised, warts, ...
# 9691                [used, for, treating, warts, Wound]
# 9692        [used, to, soften, the, skin, cells, Wound]
# 9693                          [used, for, scars, Wound]
# 9694                         [used, for, wounds, Wound]
# 9695  [used, to, treat, and, remove, raised, warts, ...
# 9696                [used, for, treating, warts, Wound]
# 9697  [used, to, treat, and, remove, raised, warts, ...
# 9698                [used, for, treating, warts, Wound]
# 9699        [used, to, soften, the, skin, cells, Wound]
# 9700                          [used, for, scars, Wound]
# 9701                         [used, for, wounds, Wound]
# 9702  [used, to, treat, and, remove, raised, warts, ...
# 9703                [used, for, treating, warts, Wound]
# 9704        [used, to, soften, the, skin, cells, Wound]
# 9705                          [used, for, scars, Wound]
# 9706                         [used, for, wounds, Wound]
# 9707  [used, to, treat, and, remove, raised, warts, ...
# 9708                [used, for, treating, warts, Wound]
# 9709  [used, to, treat, and, remove, raised, warts, ...
# 9710                [used, for, treating, warts, Wound]
# 9711        [used, to, soften, the, skin, cells, Wound]
# 9712                          [used, for, scars, Wound]
# 9713                         [used, for, wounds, Wound]
# 9714  [used, to, treat, and, remove, raised, warts, ...
# 9715                [used, for, treating, warts, Wound]
# 9716        [used, to, soften, the, skin, cells, Wound]
# 9717                          [used, for, scars, Wound]
# 9718                         [used, for, wounds, Wound]
# 9719  [used, to, treat, and, remove, raised, warts, ...
#
# [9720 rows x 3 columns]

# %%
new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# 0                      Mild to moderate acne (spots) Acne
# 1       A RET 0.025% is a prescription medicine that i...
# 2       It is used to treat acne vulgaris in people 12...
# 3       It is used to treat acne vulgaris in people 12...
# 4       treat the most severe form of acne (nodular ac...
# 5       treat the most severe form of acne (nodular ac...
# 6       treat the most severe form of acne (nodular ac...
# 7                             Â treat acne vulgarisÂ Acne
# 8                             Â treat acne vulgarisÂ Acne
# 9               Â treat mild to moderate acne(spots) Acne
# 10      treatment of dry scaly skin disorders of the s...
# 11                     Mild to moderate acne (spots) Acne
# 12      A RET 0.025% is a prescription medicine that i...
# 13      It is used to treat acne vulgaris in people 12...
# 14      It is used to treat acne vulgaris in people 12...
# 15      treat the most severe form of acne (nodular ac...
# 16      treat the most severe form of acne (nodular ac...
# 17      treat the most severe form of acne (nodular ac...
# 18                            Â treat acne vulgarisÂ Acne
# 19                            Â treat acne vulgarisÂ Acne
# 20              Â treat mild to moderate acne(spots) Acne
# 21      treatment of dry scaly skin disorders of the s...
# 22      combined with anti-acne actives of both natura...
# 23      Â gives smooth, soft, supple and fresh feeling...
# 24      It helps to reduce swelling. It can help reduc...
# 25                     Mild to moderate acne (spots) Acne
# 26      A RET 0.025% is a prescription medicine that i...
# 27      It is used to treat acne vulgaris in people 12...
# 28      It is used to treat acne vulgaris in people 12...
# 29      treat the most severe form of acne (nodular ac...
#                               ...
# 9690    used to treat and remove raised warts (usually...
# 9691                        used for treating warts Wound
# 9692                  used to soften the skin cells Wound
# 9693                                 used for scars Wound
# 9694                                used for wounds Wound
# 9695    used to treat and remove raised warts (usually...
# 9696                        used for treating warts Wound
# 9697    used to treat and remove raised warts (usually...
# 9698                        used for treating warts Wound
# 9699                  used to soften the skin cells Wound
# 9700                                 used for scars Wound
# 9701                                used for wounds Wound
# 9702    used to treat and remove raised warts (usually...
# 9703                        used for treating warts Wound
# 9704                  used to soften the skin cells Wound
# 9705                                 used for scars Wound
# 9706                                used for wounds Wound
# 9707    used to treat and remove raised warts (usually...
# 9708                        used for treating warts Wound
# 9709    used to treat and remove raised warts (usually...
# 9710                        used for treating warts Wound
# 9711                  used to soften the skin cells Wound
# 9712                                 used for scars Wound
# 9713                                used for wounds Wound
# 9714    used to treat and remove raised warts (usually...
# 9715                        used for treating warts Wound
# 9716                  used to soften the skin cells Wound
# 9717                                 used for scars Wound
# 9718                                used for wounds Wound
# 9719    used to treat and remove raised warts (usually...
# Name: tags, Length: 9720, dtype: object

# %%
new_df
# Out:
#       index                                          Drug_Name  \
# 0         1               A CN Gel(Topical) 20gmA CN Soap 75gm
# 1         2  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...
# 2         3                             ACGEL CL NANO Gel 15gm
# 3         4                                ACGEL NANO Gel 15gm
# 4         5                              Acleen 1% Lotion 25ml
# 5         6                              Aclene 0.10% Gel 15gm
# 6         7                                     Acnay Gel 10gm
# 7         8                Acne Aid Bar 50gmAcne Aid Bar 100gm
# 8         9                                   Acne UV Gel 60gm
# 9        10                            Acne UV SPF 30 Gel 30gm
# 10       11                                  Acnecure Gel 20gm
# 11       12                                   Acnedap Gel 15gm
# 12       13                              Acnedap Plus Gel 15gm
# 13       14                                   Acnehit Gel 15gm
# 14       15                                  Acnelak Soap 75gm
# 15       16                             Acnelak Clz Cream 15gm
# 16       17                              Acnelak Z Lotion 15gm
# 17       18                               Acnemoist Cream 60gm
# 18       19                                  Acnerex Soap 75gm
# 19       20  Acneril 1% Gel 10gmAcneril Tablet 10Acneril 0....
# 20       21  Acnesol 1% Solution 25mlAcnesol Gel 20gmAcneso...
# 21       22                            Acnesol A Nano Gel 15gm
# 22       23                                Acnesol CL Gel 15gm
# 23       24                                 Acnestal Soap 75gm
# 24       25  Acnestar 10mg Capsule 10'SAcnestar 2.5% Soap 7...
# 25       26        Acnetoin 20mg Capsule 10'SAcnetoin Gel 15gm
# 26       27                         Acnetoin Plus Oinment 15gm
# 27       28                        Acnetor AD 1% Ointment 15gm
# 28       29             Acnetor AD Cream 15Acnetor AD Gel 15gm
# 29       30                                   Acnewar Gel 15gm
# ...     ...                                                ...
# 9690   9691                         Hydroheal AM Ointment 15gm
# 9691   9692         Hydroheal AM Gel 50gmHydroheal AM Gel 15gm
# 9692   9693                    Hydroheal Silwash Solution 60ml
# 9693   9694  Intadine 5% Oinment 250gmIntadine Solution 500...
# 9694   9695                     Intadine HS 10% Solution 100ml
# 9695   9696                              Iteol 3 Liquid 1000ml
# 9696   9697                              Iteol H Solution 5Ltr
# 9697   9698  Placentrex CreamPlacentrex Cream 20gmPlacentre...
# 9698   9699                              Placentrex V Gel 20gm
# 9699   9700                                POVICIDAL Gel 250gm
# 9700   9701                               POVID Solution 100ml
# 9701   9702                         Povidine 5% Solution 500ml
# 9702   9703                      Povidone Iodine Ointment 20gm
# 9703   9704  Povimac Oinment 15gmPovimac Oinment 10gmPovima...
# 9704   9705                                Povimed Oinment 5gm
# 9705   9706                               Povimet Oinment 15gm
# 9706   9707                             Puridine Ointment 15gm
# 9707   9708                 Scarend Silicone Gel(Topical) 10gm
# 9708   9709                              Sepovin Ointment 15gm
# 9709   9710  Servinadine Ointment 10gmServinadine Ointment ...
# 9710   9711                             Silverex Heal Gel 15gm
# 9711   9712                           Silverex Ionic Gel 100gm
# 9712   9713                              Soludine M Cream 10gm
# 9713   9714                          Sucral Povi Ointment 20gm
# 9714   9715                              Supraheal AR Gel 20gm
# 9715   9716                                T Muce Ointment 5gm
# 9716   9717  Wokadine 10% Solution 100mlWokadine Solution 5...
# 9717   9718                               Wokadine M Onit 10gm
# 9718   9719                           Wound Fix Solution 100ml
# 9719   9720                              Wounsol Ointment 15gm
#
#                                                    tags
# 0             [Mild, to, moderate, acne, (spots), Acne]
# 1     [A, RET, 0.025%, is, a, prescription, medicine...
# 2     [It, is, used, to, treat, acne, vulgaris, in, ...
# 3     [It, is, used, to, treat, acne, vulgaris, in, ...
# 4     [treat, the, most, severe, form, of, acne, (no...
# 5     [treat, the, most, severe, form, of, acne, (no...
# 6     [treat, the, most, severe, form, of, acne, (no...
# 7                     [Â, treat, acne, vulgarisÂ, Acne]
# 8                     [Â, treat, acne, vulgarisÂ, Acne]
# 9     [Â, treat, mild, to, moderate, acne(spots), Acne]
# 10    [treatment, of, dry, scaly, skin, disorders, o...
# 11            [Mild, to, moderate, acne, (spots), Acne]
# 12    [A, RET, 0.025%, is, a, prescription, medicine...
# 13    [It, is, used, to, treat, acne, vulgaris, in, ...
# 14    [It, is, used, to, treat, acne, vulgaris, in, ...
# 15    [treat, the, most, severe, form, of, acne, (no...
# 16    [treat, the, most, severe, form, of, acne, (no...
# 17    [treat, the, most, severe, form, of, acne, (no...
# 18                    [Â, treat, acne, vulgarisÂ, Acne]
# 19                    [Â, treat, acne, vulgarisÂ, Acne]
# 20    [Â, treat, mild, to, moderate, acne(spots), Acne]
# 21    [treatment, of, dry, scaly, skin, disorders, o...
# 22    [combined, with, anti-acne, actives, of, both,...
# 23    [Â, gives, smooth,, soft,, supple, and, fresh,...
# 24    [It, helps, to, reduce, swelling., It, can, he...
# 25            [Mild, to, moderate, acne, (spots), Acne]
# 26    [A, RET, 0.025%, is, a, prescription, medicine...
# 27    [It, is, used, to, treat, acne, vulgaris, in, ...
# 28    [It, is, used, to, treat, acne, vulgaris, in, ...
# 29    [treat, the, most, severe, form, of, acne, (no...
# ...                                                 ...
# 9690  [used, to, treat, and, remove, raised, warts, ...
# 9691                [used, for, treating, warts, Wound]
# 9692        [used, to, soften, the, skin, cells, Wound]
# 9693                          [used, for, scars, Wound]
# 9694                         [used, for, wounds, Wound]
# 9695  [used, to, treat, and, remove, raised, warts, ...
# 9696                [used, for, treating, warts, Wound]
# 9697  [used, to, treat, and, remove, raised, warts, ...
# 9698                [used, for, treating, warts, Wound]
# 9699        [used, to, soften, the, skin, cells, Wound]
# 9700                          [used, for, scars, Wound]
# 9701                         [used, for, wounds, Wound]
# 9702  [used, to, treat, and, remove, raised, warts, ...
# 9703                [used, for, treating, warts, Wound]
# 9704        [used, to, soften, the, skin, cells, Wound]
# 9705                          [used, for, scars, Wound]
# 9706                         [used, for, wounds, Wound]
# 9707  [used, to, treat, and, remove, raised, warts, ...
# 9708                [used, for, treating, warts, Wound]
# 9709  [used, to, treat, and, remove, raised, warts, ...
# 9710                [used, for, treating, warts, Wound]
# 9711        [used, to, soften, the, skin, cells, Wound]
# 9712                          [used, for, scars, Wound]
# 9713                         [used, for, wounds, Wound]
# 9714  [used, to, treat, and, remove, raised, warts, ...
# 9715                [used, for, treating, warts, Wound]
# 9716        [used, to, soften, the, skin, cells, Wound]
# 9717                          [used, for, scars, Wound]
# 9718                         [used, for, wounds, Wound]
# 9719  [used, to, treat, and, remove, raised, warts, ...
#
# [9720 rows x 3 columns]

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df
# Out:
#       index                                          Drug_Name  \
# 0         1               A CN Gel(Topical) 20gmA CN Soap 75gm
# 1         2  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...
# 2         3                             ACGEL CL NANO Gel 15gm
# 3         4                                ACGEL NANO Gel 15gm
# 4         5                              Acleen 1% Lotion 25ml
# 5         6                              Aclene 0.10% Gel 15gm
# 6         7                                     Acnay Gel 10gm
# 7         8                Acne Aid Bar 50gmAcne Aid Bar 100gm
# 8         9                                   Acne UV Gel 60gm
# 9        10                            Acne UV SPF 30 Gel 30gm
# 10       11                                  Acnecure Gel 20gm
# 11       12                                   Acnedap Gel 15gm
# 12       13                              Acnedap Plus Gel 15gm
# 13       14                                   Acnehit Gel 15gm
# 14       15                                  Acnelak Soap 75gm
# 15       16                             Acnelak Clz Cream 15gm
# 16       17                              Acnelak Z Lotion 15gm
# 17       18                               Acnemoist Cream 60gm
# 18       19                                  Acnerex Soap 75gm
# 19       20  Acneril 1% Gel 10gmAcneril Tablet 10Acneril 0....
# 20       21  Acnesol 1% Solution 25mlAcnesol Gel 20gmAcneso...
# 21       22                            Acnesol A Nano Gel 15gm
# 22       23                                Acnesol CL Gel 15gm
# 23       24                                 Acnestal Soap 75gm
# 24       25  Acnestar 10mg Capsule 10'SAcnestar 2.5% Soap 7...
# 25       26        Acnetoin 20mg Capsule 10'SAcnetoin Gel 15gm
# 26       27                         Acnetoin Plus Oinment 15gm
# 27       28                        Acnetor AD 1% Ointment 15gm
# 28       29             Acnetor AD Cream 15Acnetor AD Gel 15gm
# 29       30                                   Acnewar Gel 15gm
# ...     ...                                                ...
# 9690   9691                         Hydroheal AM Ointment 15gm
# 9691   9692         Hydroheal AM Gel 50gmHydroheal AM Gel 15gm
# 9692   9693                    Hydroheal Silwash Solution 60ml
# 9693   9694  Intadine 5% Oinment 250gmIntadine Solution 500...
# 9694   9695                     Intadine HS 10% Solution 100ml
# 9695   9696                              Iteol 3 Liquid 1000ml
# 9696   9697                              Iteol H Solution 5Ltr
# 9697   9698  Placentrex CreamPlacentrex Cream 20gmPlacentre...
# 9698   9699                              Placentrex V Gel 20gm
# 9699   9700                                POVICIDAL Gel 250gm
# 9700   9701                               POVID Solution 100ml
# 9701   9702                         Povidine 5% Solution 500ml
# 9702   9703                      Povidone Iodine Ointment 20gm
# 9703   9704  Povimac Oinment 15gmPovimac Oinment 10gmPovima...
# 9704   9705                                Povimed Oinment 5gm
# 9705   9706                               Povimet Oinment 15gm
# 9706   9707                             Puridine Ointment 15gm
# 9707   9708                 Scarend Silicone Gel(Topical) 10gm
# 9708   9709                              Sepovin Ointment 15gm
# 9709   9710  Servinadine Ointment 10gmServinadine Ointment ...
# 9710   9711                             Silverex Heal Gel 15gm
# 9711   9712                           Silverex Ionic Gel 100gm
# 9712   9713                              Soludine M Cream 10gm
# 9713   9714                          Sucral Povi Ointment 20gm
# 9714   9715                              Supraheal AR Gel 20gm
# 9715   9716                                T Muce Ointment 5gm
# 9716   9717  Wokadine 10% Solution 100mlWokadine Solution 5...
# 9717   9718                               Wokadine M Onit 10gm
# 9718   9719                           Wound Fix Solution 100ml
# 9719   9720                              Wounsol Ointment 15gm
#
#                                                    tags
# 0                    Mild to moderate acne (spots) Acne
# 1     A RET 0.025% is a prescription medicine that i...
# 2     It is used to treat acne vulgaris in people 12...
# 3     It is used to treat acne vulgaris in people 12...
# 4     treat the most severe form of acne (nodular ac...
# 5     treat the most severe form of acne (nodular ac...
# 6     treat the most severe form of acne (nodular ac...
# 7                           Â treat acne vulgarisÂ Acne
# 8                           Â treat acne vulgarisÂ Acne
# 9             Â treat mild to moderate acne(spots) Acne
# 10    treatment of dry scaly skin disorders of the s...
# 11                   Mild to moderate acne (spots) Acne
# 12    A RET 0.025% is a prescription medicine that i...
# 13    It is used to treat acne vulgaris in people 12...
# 14    It is used to treat acne vulgaris in people 12...
# 15    treat the most severe form of acne (nodular ac...
# 16    treat the most severe form of acne (nodular ac...
# 17    treat the most severe form of acne (nodular ac...
# 18                          Â treat acne vulgarisÂ Acne
# 19                          Â treat acne vulgarisÂ Acne
# 20            Â treat mild to moderate acne(spots) Acne
# 21    treatment of dry scaly skin disorders of the s...
# 22    combined with anti-acne actives of both natura...
# 23    Â gives smooth, soft, supple and fresh feeling...
# 24    It helps to reduce swelling. It can help reduc...
# 25                   Mild to moderate acne (spots) Acne
# 26    A RET 0.025% is a prescription medicine that i...
# 27    It is used to treat acne vulgaris in people 12...
# 28    It is used to treat acne vulgaris in people 12...
# 29    treat the most severe form of acne (nodular ac...
# ...                                                 ...
# 9690  used to treat and remove raised warts (usually...
# 9691                      used for treating warts Wound
# 9692                used to soften the skin cells Wound
# 9693                               used for scars Wound
# 9694                              used for wounds Wound
# 9695  used to treat and remove raised warts (usually...
# 9696                      used for treating warts Wound
# 9697  used to treat and remove raised warts (usually...
# 9698                      used for treating warts Wound
# 9699                used to soften the skin cells Wound
# 9700                               used for scars Wound
# 9701                              used for wounds Wound
# 9702  used to treat and remove raised warts (usually...
# 9703                      used for treating warts Wound
# 9704                used to soften the skin cells Wound
# 9705                               used for scars Wound
# 9706                              used for wounds Wound
# 9707  used to treat and remove raised warts (usually...
# 9708                      used for treating warts Wound
# 9709  used to treat and remove raised warts (usually...
# 9710                      used for treating warts Wound
# 9711                used to soften the skin cells Wound
# 9712                               used for scars Wound
# 9713                              used for wounds Wound
# 9714  used to treat and remove raised warts (usually...
# 9715                      used for treating warts Wound
# 9716                used to soften the skin cells Wound
# 9717                               used for scars Wound
# 9718                              used for wounds Wound
# 9719  used to treat and remove raised warts (usually...
#
# [9720 rows x 3 columns]

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df
# Out:
#       index                                          Drug_Name  \
# 0         1               A CN Gel(Topical) 20gmA CN Soap 75gm
# 1         2  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...
# 2         3                             ACGEL CL NANO Gel 15gm
# 3         4                                ACGEL NANO Gel 15gm
# 4         5                              Acleen 1% Lotion 25ml
# 5         6                              Aclene 0.10% Gel 15gm
# 6         7                                     Acnay Gel 10gm
# 7         8                Acne Aid Bar 50gmAcne Aid Bar 100gm
# 8         9                                   Acne UV Gel 60gm
# 9        10                            Acne UV SPF 30 Gel 30gm
# 10       11                                  Acnecure Gel 20gm
# 11       12                                   Acnedap Gel 15gm
# 12       13                              Acnedap Plus Gel 15gm
# 13       14                                   Acnehit Gel 15gm
# 14       15                                  Acnelak Soap 75gm
# 15       16                             Acnelak Clz Cream 15gm
# 16       17                              Acnelak Z Lotion 15gm
# 17       18                               Acnemoist Cream 60gm
# 18       19                                  Acnerex Soap 75gm
# 19       20  Acneril 1% Gel 10gmAcneril Tablet 10Acneril 0....
# 20       21  Acnesol 1% Solution 25mlAcnesol Gel 20gmAcneso...
# 21       22                            Acnesol A Nano Gel 15gm
# 22       23                                Acnesol CL Gel 15gm
# 23       24                                 Acnestal Soap 75gm
# 24       25  Acnestar 10mg Capsule 10'SAcnestar 2.5% Soap 7...
# 25       26        Acnetoin 20mg Capsule 10'SAcnetoin Gel 15gm
# 26       27                         Acnetoin Plus Oinment 15gm
# 27       28                        Acnetor AD 1% Ointment 15gm
# 28       29             Acnetor AD Cream 15Acnetor AD Gel 15gm
# 29       30                                   Acnewar Gel 15gm
# ...     ...                                                ...
# 9690   9691                         Hydroheal AM Ointment 15gm
# 9691   9692         Hydroheal AM Gel 50gmHydroheal AM Gel 15gm
# 9692   9693                    Hydroheal Silwash Solution 60ml
# 9693   9694  Intadine 5% Oinment 250gmIntadine Solution 500...
# 9694   9695                     Intadine HS 10% Solution 100ml
# 9695   9696                              Iteol 3 Liquid 1000ml
# 9696   9697                              Iteol H Solution 5Ltr
# 9697   9698  Placentrex CreamPlacentrex Cream 20gmPlacentre...
# 9698   9699                              Placentrex V Gel 20gm
# 9699   9700                                POVICIDAL Gel 250gm
# 9700   9701                               POVID Solution 100ml
# 9701   9702                         Povidine 5% Solution 500ml
# 9702   9703                      Povidone Iodine Ointment 20gm
# 9703   9704  Povimac Oinment 15gmPovimac Oinment 10gmPovima...
# 9704   9705                                Povimed Oinment 5gm
# 9705   9706                               Povimet Oinment 15gm
# 9706   9707                             Puridine Ointment 15gm
# 9707   9708                 Scarend Silicone Gel(Topical) 10gm
# 9708   9709                              Sepovin Ointment 15gm
# 9709   9710  Servinadine Ointment 10gmServinadine Ointment ...
# 9710   9711                             Silverex Heal Gel 15gm
# 9711   9712                           Silverex Ionic Gel 100gm
# 9712   9713                              Soludine M Cream 10gm
# 9713   9714                          Sucral Povi Ointment 20gm
# 9714   9715                              Supraheal AR Gel 20gm
# 9715   9716                                T Muce Ointment 5gm
# 9716   9717  Wokadine 10% Solution 100mlWokadine Solution 5...
# 9717   9718                               Wokadine M Onit 10gm
# 9718   9719                           Wound Fix Solution 100ml
# 9719   9720                              Wounsol Ointment 15gm
#
#                                                    tags
# 0                    mild to moderate acne (spots) acne
# 1     a ret 0.025% is a prescription medicine that i...
# 2     it is used to treat acne vulgaris in people 12...
# 3     it is used to treat acne vulgaris in people 12...
# 4     treat the most severe form of acne (nodular ac...
# 5     treat the most severe form of acne (nodular ac...
# 6     treat the most severe form of acne (nodular ac...
# 7                           â treat acne vulgarisâ acne
# 8                           â treat acne vulgarisâ acne
# 9             â treat mild to moderate acne(spots) acne
# 10    treatment of dry scaly skin disorders of the s...
# 11                   mild to moderate acne (spots) acne
# 12    a ret 0.025% is a prescription medicine that i...
# 13    it is used to treat acne vulgaris in people 12...
# 14    it is used to treat acne vulgaris in people 12...
# 15    treat the most severe form of acne (nodular ac...
# 16    treat the most severe form of acne (nodular ac...
# 17    treat the most severe form of acne (nodular ac...
# 18                          â treat acne vulgarisâ acne
# 19                          â treat acne vulgarisâ acne
# 20            â treat mild to moderate acne(spots) acne
# 21    treatment of dry scaly skin disorders of the s...
# 22    combined with anti-acne actives of both natura...
# 23    â gives smooth, soft, supple and fresh feeling...
# 24    it helps to reduce swelling. it can help reduc...
# 25                   mild to moderate acne (spots) acne
# 26    a ret 0.025% is a prescription medicine that i...
# 27    it is used to treat acne vulgaris in people 12...
# 28    it is used to treat acne vulgaris in people 12...
# 29    treat the most severe form of acne (nodular ac...
# ...                                                 ...
# 9690  used to treat and remove raised warts (usually...
# 9691                      used for treating warts wound
# 9692                used to soften the skin cells wound
# 9693                               used for scars wound
# 9694                              used for wounds wound
# 9695  used to treat and remove raised warts (usually...
# 9696                      used for treating warts wound
# 9697  used to treat and remove raised warts (usually...
# 9698                      used for treating warts wound
# 9699                used to soften the skin cells wound
# 9700                               used for scars wound
# 9701                              used for wounds wound
# 9702  used to treat and remove raised warts (usually...
# 9703                      used for treating warts wound
# 9704                used to soften the skin cells wound
# 9705                               used for scars wound
# 9706                              used for wounds wound
# 9707  used to treat and remove raised warts (usually...
# 9708                      used for treating warts wound
# 9709  used to treat and remove raised warts (usually...
# 9710                      used for treating warts wound
# 9711                used to soften the skin cells wound
# 9712                               used for scars wound
# 9713                              used for wounds wound
# 9714  used to treat and remove raised warts (usually...
# 9715                      used for treating warts wound
# 9716                used to soften the skin cells wound
# 9717                               used for scars wound
# 9718                              used for wounds wound
# 9719  used to treat and remove raised warts (usually...
#
# [9720 rows x 3 columns]

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (3.3)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from nltk) (1.11.0)
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 21.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
# !pip install -U scikit-learn scipy matplotlib

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words='english',max_features=5000)

# %%
def stem(text):
  y = []

  for i in text.split():
    y.append(ps.stem(i))

  return " ".join(y)

# %%
new_df['tags'] = new_df['tags'].apply(stem)

# %%
cv.fit_transform(new_df['tags']).toarray().shape

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
cv.get_feature_names()

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(vectors)

# %%
similarity = cosine_similarity(vectors)

# %%
similarity[1]

# %%
def recommend(medicine):
    medicine_index = new_df[new_df['Drug_Name'] == medicine].index[0]
    distances = similarity[medicine_index]
    medicines_list = sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]
    
    for i in medicines_list:
        print(new_df.iloc[i[0]].Drug_Name)

# %%
recommend("Paracetamol 125mg Syrup 60mlParacetamol 500mg Tablet 10'S")

# %%
import pickle

# %%
pickle.dump(new_df.to_dict(),open('medicine_dict.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))
